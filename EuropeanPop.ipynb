# %%
import csv
import numpy as np
import pandas as pd

# %%
# read the CSV file using Pandas
df = pd.read_csv('eur.pop.rev.csv')

# %%
df.fillna(0)
# Out:
#                     European Population        1989       1990       1991  \
# 0                                      0          0          0          0
# 1                                      0   01.01.89   01.01.90   01.01.91
# 2                                Austria    7602431    7660345    7790957
# 3                                Belgium    9927600    9947800    9987000
# 4                                Denmark    5129800    5135400    5146500
# 5                                Finland    4954359    4974383    4998478
# 6                                 France   56269800          0   56893000
# 7                                Germany   61715000   62678000   79753000
# 8                                Iceland     253500     255708     259577
# 9                                Ireland    3526600    3505500    3519000
# 10                                 Italy   57504700   57576400   57746200
# 11                             Luxemburg     374900     379300     384400
# ...

# %%
#Print each country that has more than 1,000,000 people in 1995
df1 = df[(df.filter(like='Year') > 1000000) .any(axis=1)]
print(df1)
# Out:
# Empty DataFrame
# Columns: [European Population , 1989, 1990, 1991, 1992, 1993, 1994, 1995]
# Index: []

# %%
#Print the average population in the United Kingdom over those seven years.
calc = round(df.groupby(['1989','1990','1991','1992','1993','1994','1995'])["European Population"].mean(), 2)
print('\nAverage population in UK')
print(calc)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [64], in <cell line: 2>()
#       1 #Print the average population in the United Kingdom over those seven years.
# ----> 2 calc = round(df.groupby(['1989','1990','1991','1992','1993','1994','1995'])["European Population"].mean(), 2)
#       3 print('\nAverage population in UK')
#       4 print(calc)
#
# File /opt/conda/envs/anaconda-2022.05-py39/lib/python3.9/site-packages/pandas/core/groupby/generic.py:1338, in DataFrameGroupBy.__getitem__(self, key)
#    1329 if isinstance(key, tuple) and len(key) > 1:
#    1330     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1331     # valid syntax, so don't raise warning
#    1332     warnings.warn(
#    1333         "Indexing with multiple keys (implicitly converted to a tuple "
#    1334         "of keys) will be deprecated, use a list instead.",
# ...

# %%
def total_population():
    totalPop=0
    #count=0
    for str3 in EuropeanPop
